# %%
import os
os.listdir()
# pip install pandas
# pip install ipython
# pip install jupyter
#  jupyter notebook
# pip install xlrd    (for pandas.read_excel())
# Out:
# ['.ipynb_checkpoints',
#  '.project',
#  '.pydevproject',
#  'app1.py',
#  'data.json',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Untitled.ipynb']

# %%
import pandas
df=pandas.read_csv("supermarkets.csv") # ,header=None
df.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df=pandas.read_json("supermarkets.json") # ,header=None
df.set_index("ID")
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df=pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df.set_index("ID")
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df7=df.set_index("Address")
df7.loc["735 Dolores St":"3995 23rd St","City":"Country"]
# Out:
#                          City             State Country
# Address
# 735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St     San Francisco  California 94114     USA
# 3995 23rd St    San Francisco          CA 94114     USA

# %%
df6 = df7
df = pandas.merge(left=df6, right=df7, on="ID")
df
# Out:
#    ID         City_x           State_x Country_x Supermarket Name_x  \
# 0   1  San Francisco          CA 94114       USA            Madeira
# 1   2  San Francisco          CA 94119       USA        Bready Shop
# 2   3  San Francisco  California 94114       USA        Super River
# 3   4  San Francisco          CA 94114       USA         Ben's Shop
# 4   5  San Francisco        California       USA            Sanchez
# 5   6  San Francisco          CA 94114       USA         Richvalley
#
#    Number of Employees_x         City_y           State_y Country_y  \
# 0                      8  San Francisco          CA 94114       USA
# 1                     15  San Francisco          CA 94119       USA
# 2                     25  San Francisco  California 94114       USA
# 3                     10  San Francisco          CA 94114       USA
# 4                     12  San Francisco        California       USA
# 5                     20  San Francisco          CA 94114       USA
#
#   Supermarket Name_y  Number of Employees_y
# 0            Madeira                      8
# 1        Bready Shop                     15
# 2        Super River                     25
# 3         Ben's Shop                     10
# 4            Sanchez                     12
# 5         Richvalley                     20

# %%
df7.iloc[1:3,1:3]
# Out:
#                          City             State
# Address
# 735 Dolores St  San Francisco          CA 94119
# 332 Hill St     San Francisco  California 94114

# %%
df7.ix[1:3,"City":"Country"]
# Out:
#                          City             State Country
# Address
# 735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St     San Francisco  California 94114     USA

# %%
df7.drop("735 Dolores St",0)  # ,1 for columns
# Out:
#                  ID           City             State Country Supermarket Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA          Madeira
# 332 Hill St       3  San Francisco  California 94114     USA      Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA       Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA          Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA       Richvalley
#
#                  Number of Employees
# Address
# 3666 21st St                       8
# 332 Hill St                       25
# 3995 23rd St                      10
# 1056 Sanchez St                   12
# 551 Alvarado St                   20

# %%
df7.index
df7.columns
# Out:
# Index(['ID', 'City', 'State', 'Country', 'Supermarket Name',
#        'Number of Employees'],
#       dtype='object')

# %%
df7["Continent"] = df7.shape[0] * ["North America"]
df7["Continent"] = df7["Country"] + ", " + "North America"
df7
# Out:
#                  ID           City             State Country Supermarket Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA          Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA      Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA      Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA       Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA          Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA       Richvalley
#
#                  Number of Employees           Continent
# Address
# 3666 21st St                       8  USA, North America
# 735 Dolores St                    15  USA, North America
# 332 Hill St                       25  USA, North America
# 3995 23rd St                      10  USA, North America
# 1056 Sanchez St                   12  USA, North America
# 551 Alvarado St                   20  USA, North America

# %%
from geopy.geocoders import Nominatim
import pandas
nom=Nominatim(scheme="http")
n=nom.geocode("1 Calea Apeductului, Bucharest, Romania")
n
# Out:
# Location(1, Calea Apeductului, București, Militari, Sector 6, București, 060911, România, (44.4389419, 26.0348224, 0.0))

# %%
df7 = pandas.read_csv("supermarkets.csv")
df7["FullAddress"] = df7["Address"] + ", " + df7["City"] + ", " + df7["State"] + ", " + df7["Country"]
df7["Coord"] = df7["FullAddress"].apply(nom.geocode)
df7["Latitude"] = df7["Coord"].apply(lambda x: x.latitude if x != None else None)
df7["Longitude"] = df7["Coord"].apply(lambda x: x.longitude if x != None else None)
df7
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                        FullAddress  \
# 0          8         3666 21st St, San Francisco, CA 94114, USA
# 1         15       735 Dolores St, San Francisco, CA 94119, USA
# 2         25  332 Hill St, San Francisco, California 94114, USA
# 3         10         3995 23rd St, San Francisco, CA 94114, USA
# 4         12    1056 Sanchez St, San Francisco, California, USA
# 5         20      551 Alvarado St, San Francisco, CA 94114, USA
#
#                                                Coord
# 0  (21st Street, Mission District, SF, California...
# 1                                               None
# 2  (Hill Street, Liberty Street Historic District...
# 3  (3995, 23rd Street, Noe Valley, SF, California...
# 4  (Sanchez Street, Noe Valley, SF, California, 9...
# 5  (Alvarado Street, Noe Valley, SF, California, ...

# %%
#from bs4 import BeautefulSoup
import requests

r=requests.get("https://en.wikipedia.org/wiki/Eagle")
print(r.content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-ca963f2e50c7> in <module>()
#       1 #from bs4 import BeautefulSoup
# ----> 2 import requests
#       3
#       4 r=requests.get("https://en.wikipedia.org/wiki/Eagle")
#       5 print(r.content)
#
# ModuleNotFoundError: No module named 'requests'
